# %%
import pickle
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from random import randint
import warnings
warnings.filterwarnings("ignore")

with open('tfidf_vectorizer.pkl', 'rb') as vectorizer_file:
    tfidf_vectorizer = pickle.load(vectorizer_file)
with open('mlb.pkl', 'rb') as mlb_file:
    mlb = pickle.load(mlb_file)

with open('random_forest_classifier.pkl', 'rb') as classifier_file:
    rf_classifier = pickle.load(classifier_file)

# %%
import numpy as np



full_text=str('Leo')
dec=str('Parthiban is a mild mannered cafe owner in Kashmir, who he fends off a gang of murderous thugs, and gains attention from a drug cartel claiming he was once a part of them.')
input_text=full_text+'_'+dec
input_text=[input_text]
input_vector = tfidf_vectorizer.transform(input_text).toarray()
predicted_probabilities = rf_classifier.predict_proba(input_vector)
    
new=list()
for i in range(len(predicted_probabilities)):
    new.append(1-predicted_probabilities[i][0][0])
treshold=.24
pred=list()
for i in new:
    if i >= treshold:
        pred.append(1)
    else:
        pred.append(0)
l=np.array([pred])
predicted_labels_text = mlb.inverse_transform(l)

prediction_label = predicted_labels_text

# %%
prediction_label
# Out:
# [('Action', 'Crime', 'Drama')]

# %%
import ast
data = pd.read_csv('metadata.csv', low_memory=False)
data['genres'] = data['genres'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])
data['new']=data['genres']
def eng(x):
    llsst=[]
    for i in x:
        for j in i:
            if j=='name':
                llsst.append(i[j])
    return llsst


data['new']=data['genres'].apply(lambda x: eng(x))

# %%
import ast

data['spoken_languages'] = data['spoken_languages'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 4
#       1 import ast
#       3 data = data[data['adult'].isin(['False', 'True'])]
# ----> 4 data['spoken_languages'] = data['spoken_languages'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
# ...

# %%
# Out:
# 'en'

# %%
def eng(x):
    llsst=[]
    for i in x:
        for j in i:
            if j=='iso_639_1':
                llsst.append(i[j])
    return llsst



data['language']=data['spoken_languages'].apply(lambda x: eng(x))

# %%
data['adult'] = data['adult'].astype(bool)
data['adult'].replace({True: 1, False: 0}, inplace=True)

# %%
data['belongs_to_collection'] = data['belongs_to_collection'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

# %%
f=data['belongs_to_collection'][0]
f['name']
# Out:
# 'Toy Story Collection'

# %%
def eng(x):
    llsst=[]
    if x==[]:
        #print(x)
        llsst.append(None)
    else:
        
        for i in x:
            if i=='name':
                llsst.append(x[i])

    return llsst




data['collection']=data['belongs_to_collection'].apply(lambda x: eng(x))

# %%
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'new', 'language', 'collection'],
#       dtype='object')

# %%
data=data.drop(columns=['belongs_to_collection', 'budget','genres','homepage','id','budget','imdb_id','vote_count','video','runtime'])

# %%
data=data.drop(columns=['poster_path','poster_path'])

# %%
data['production_companies'] = data['production_companies'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

# %%
data
# Out:
#        adult original_language               original_title  \
# 0          1                en                    Toy Story
# 1          1                en                      Jumanji
# 2          1                en             Grumpier Old Men
# 3          1                en            Waiting to Exhale
# 4          1                en  Father of the Bride Part II
# ...      ...               ...                          ...
# 45461      1                fa                      رگ خواب
# 45462      1                tl          Siglo ng Pagluluwal
# 45463      1                en                     Betrayal
# 45464      1                en          Satana likuyushchiy
# 45465      1                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# ...

# %%
data.to_csv('new.csv', index=False)

# %%
def eng(x):
    llsst=[]
    if x==[]:
        #print(x)
        llsst.append(None)
    else:
        
        for i in x:
            if i=='name':
                llsst.append(x[i])

    return llsst




data['production_companies']=data['production_companies'].apply(lambda x: eng(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 data['production_companies']=data['production_companies'].apply(lambda x: eng(x))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# ...

# %%
data.columns
# Out:
# Index(['adult', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'spoken_languages',
#        'status', 'tagline', 'title', 'vote_average', 'new', 'language',
#        'collection'],
#       dtype='object')

# %%
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0          1  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1          1                                                 []  65000000
# 2          1  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3          1                                                 []  16000000
# 4          1  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461      1                                                 []         0
# 45462      1                                                 []         0
# 45463      1                                                 []         0
# 45464      1                                                 []         0
# 45465      1                                                 []         0
#
#                                                   genres  \
# ...

# %%
similar_movies = df[df['genre'] == predicted_genre]
# Print similar movies based on the predicted label
print("Similar Movies Based on Predicted Genre:")
for idx, row in similar_movies.iterrows():
    print(f"{row['title']} - {row['description']}")
